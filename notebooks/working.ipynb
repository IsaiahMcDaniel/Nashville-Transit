# %%
from google.transit import gtfs_realtime_pb2
from protobuf_to_dict import protobuf_to_dict
from pathlib import Path
import requests
import pandas as pd
from gtfs_feeds import GtfsFeeds

# %%
vehicle_pos = 'http://transitdata.nashvillemta.org/TMGTFSRealTimeWebService/alert/alerts.pb'

# %%
g = GtfsFeeds(url=vehicle_pos,file_name='schema_data')
# Load GTFS data
g.fetch()
# Out:
#       id                          alert.active_period  \
# 0  45987   [{'start': 1740387600, 'end': 1744617600}]
# 1  46339  [{'start': 1742814000, 'end': 32503701600}]
# 2  46389  [{'start': 1743001620, 'end': 32503701600}]
# 3  46498  [{'start': 1743617760, 'end': 32503701600}]
# 4  46499  [{'start': 1743617760, 'end': 32503701600}]
# 5  46558  [{'start': 1743686280, 'end': 32503701600}]
#
#                                alert.informed_entity  alert.effect  \
# 0        [{'route_id': '17', 'stop_id': '12ADIVSF'}]             4
# 1         [{'route_id': '3', 'stop_id': 'HARBOSWM'}]             4
# 2                               [{'route_id': '84'}]             9
# 3                               [{'route_id': '77'}]             4
# 4                               [{'route_id': '77'}]             4
# 5  [{'route_id': '84', 'stop_id': '8ABRONM'}, {'r...             4
#
#                        alert.header_text.translation  \
# 0  [{'text': 'Detour in effect on route 17 12TH A...
# ...
